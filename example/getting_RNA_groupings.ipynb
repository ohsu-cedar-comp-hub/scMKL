# %% [markdown]
# ## Creating RNA feature groupings to be used with scMKL
# There are three ways to read-in a grouping dictionary as a dictionary where grouping_dictionary['Group1_name'] = [gene_1, gene_2, ... gene_n] (dict[str] : [set | np.ndarray | list | tuple | pd.Series])
# 1) Reading in a gene set library that is saved as a pickle file
# 2) Reading in a gene set library that is saved as a gmt file
# 3) Using GSEApy to download one of their many gene sets across several organisms
#
# **NOTE: Although we are using gene symbols here, we recommend using gene IDs for both your grouping dictionary and scRNA feature array rather than gene symbols as they are more ambiguous.**

# %%
# Importing GSEApy
import gseapy

# Importing numpy and pickle for data manipulation and loading/saving
import numpy as np
import pickle

# %% [markdown]
# ### Reading in a gene set library that is saved as a pickle file

# %%
pickled_grouping = np.load("/home/vangordi/projects/scMKL/scMKL/example/data/RNA_hallmark_groupings.pkl", allow_pickle = True)
print(pickled_grouping)
# Out:
# {'HALLMARK_TNFA_SIGNALING_VIA_NFKB': {'GEM', 'BCL6', 'ICAM1', 'AREG', 'PTGS2', 'SPSB1', 'SDC4', 'CXCL6', 'TRIB1', 'DUSP2', 'IL6ST', 'EGR2', 'PHLDA1', 'SQSTM1', 'TRIP10', 'CFLAR', 'PDLIM5', 'BTG2', 'CCL2', 'DNAJB4', 'MAFF', 'PNRC1', 'LAMB3', 'NFKB1', 'CCN1', 'CEBPB', 'IFIH1', 'DENND5A', 'IRF1', 'TSC22D1', 'ID2', 'SNN', 'IL12B', 'ZFP36', 'ICOSLG', 'IL23A', 'RIPK2', 'IL18', 'PER1', 'HBEGF', 'KLF6', 'PLEK', 'SAT1', 'CD83', 'TLR2', 'SLC2A3', 'TNFAIP3', 'CXCL2', 'INHBA', 'KLF10', 'IRS2', 'MSC', 'SERPINB2', 'TIPARP', 'KDM6B', 'IL1A', 'GFPT2', 'MCL1', 'SLC16A6', 'SLC2A6', 'F2RL1', 'BTG1', 'TAP1', 'PANX1', 'GADD45A', 'KLF2', 'CSF1', 'GADD45B', 'CEBPD', 'PPP1R15A', 'PTX3', 'NR4A1', 'STAT5A', 'CXCL3', 'IFIT2', 'BCL2A1', 'BHLHE40', 'JAG1', 'VEGFA', 'FJX1', 'RELA', 'ZC3H12A', 'LIF', 'TNFAIP6', 'IER2', 'EDN1', 'CCND1', 'BIRC3', 'BCL3', 'REL', 'SGK1', 'NFKB2', 'F3', 'DUSP4', 'TUBB2A', 'OLR1', 'CD69', 'GCH1', 'CXCL1', 'ABCA1', 'MAP2K3', 'HES1', 'TNFAIP8', 'BIRC2', 'MAP3K8', 'DRAM1', 'EIF1', 'IL7R', 'PDE4B', 'EHD1', 'TNFAIP2', 'ACKR3', 'TANK', 'NR4A2', 'PLK2', 'SIK1', 'ETS2', 'RIGI', 'FUT4', 'IER3', 'NFE2L2', 'NFIL3', 'SERPINB8', 'YRDC', 'RCAN1', 'B4GALT1', 'FOSB', 'TNFRSF9', 'IER5', 'JUN', 'TRAF1', 'RNF19B', 'PLAUR', 'BMP2', 'NINJ1', 'IL6', 'NFKBIA', 'CXCL11', 'SOCS3', 'TGIF1', 'CCRL2', 'RELB', 'CCNL1', 'BTG3', 'CSF2', 'SMAD3', 'TNIP1', 'ATF3', 'NFKBIE', 'PMEPA1', 'CDKN1A', 'IL1B', 'PFKFB3', 'CCL4', 'FOSL1', 'CD80', 'DUSP1', 'FOS', 'LDLR', 'G0S2', 'TNFSF9', 'FOSL2', 'TNF', 'EGR1', 'CCL20', 'NR4A3', 'PLAU', 'PTGER4', 'RHOB', 'CLCF1', 'PLPP3', 'NFAT5', 'KYNU', 'GPR183', 'LITAF', 'CXCL10', 'MARCKS', 'TNIP2', 'KLF9', 'NAMPT', 'IFNGR2', 'DUSP5', 'SOD2', 'KLF4', 'ATP2B1', 'IL15RA', 'SPHK1', 'PHLDA2', 'SERPINE1', 'B4GALT5', 'MXD1', 'TNC', 'MYC', 'CD44', 'PTPRE', 'EFNA1', 'CCL5', 'JUNB', 'EGR3', 'ZBTB10'}, 'HALLMARK_HYPOXIA': {'CAV1', 'STBD1', 'PKLR', 'CCN5', 'SDC4', 'CSRP2', 'P4HA2', 'PLIN2', 'DPYSL4', 'CCNG2', 'B3GALT6', 'BCL2', 'KDM3A', 'TPI1', 'DTNA', 'MIF', 'GCK', 'AK4', 'PDGFB', 'MYH9', 'DDIT3', 'CAVIN3', 'ALDOC', 'CITED2', 'ILVBL', 'AKAP12', 'NCAN', 'PFKL', 'MAFF', 'PNRC1', 'TES', 'FOXO3', 'ERO1A', 'CCN1', 'WSB1', 'SLC25A1', 'PPARGC1A', 'ZFP36', 'IGFBP1', 'ANXA2', 'KLHL24', 'LDHA', 'PGF', 'FAM162A', 'KLF6', 'GYS1', 'LDHC', 'MT1E', 'PLAC8', 'CHST2', 'SLC2A3', 'TNFAIP3', 'PGK1', 'HMOX1', 'EFNA3', 'NDRG1', 'BNIP3L', 'IRS2', 'CXCR4', 'PIM1', 'PHKG1', 'HDLBP', 'TIPARP', 'KLF7', 'HSPA5', 'ALDOA', 'BTG1', 'VHL', 'VLDLR', 'JMJD6', 'FBP1', 'HAS1', 'PDK3', 'STC1', 'HOXB9', 'PPP1R15A', 'SDC3', 'ANKZF1', 'GPI', 'S100A4', 'P4HA1', 'BHLHE40', 'BCAN', 'GALK1', 'EGFR', 'VEGFA', 'DCN', 'SLC37A4', 'KIF5A', 'EDN2', 'PCK1', 'NDST2', 'SCARB1', 'STC2', 'INHA', 'PFKP', 'NAGK', 'HEXA', 'PAM', 'F3', 'B4GALNT2', 'SDC2', 'TPD52', 'ALDOB', 'ADM', 'TGM2', 'CDKN1B', 'LOX', 'TPBG', 'SLC2A1', 'EXT1', 'KDELR3', 'SRPX', 'XPNPEP1', 'DDIT4', 'ACKR3', 'BGN', 'ISG20', 'IER3', 'TKTL1', 'NFIL3', 'ERRFI1', 'MXI1', 'ENO3', 'JUN', 'LARGE1', 'PPP1R3C', 'CP', 'PLAUR', 'GCNT2', 'BRS3', 'CAVIN1', 'LALBA', 'TMEM45A', 'GPC3', 'ZNF292', 'RRAGD', 'ETS1', 'HK1', 'IL6', 'RBPJ', 'ENO2', 'PPFIA4', 'CCN2', 'NOCT', 'PYGM', 'GLRX', 'RORA', 'GRHPR', 'HS3ST1', 'NR3C1', 'SLC2A5', 'LXN', 'CDKN1C', 'TGFBI', 'ATF3', 'CDKN1A', 'GAPDH', 'HK2', 'NEDD4L', 'SLC6A6', 'CHST3', 'ENO1', 'PFKFB3', 'PDK1', 'GAA', 'DUSP1', 'NDST1', 'FOS', 'CA12', 'IGFBP3', 'FOSL2', 'ANGPTL4', 'SAP30', 'CASP6', 'PRKCA', 'SELENBP1', 'MAP3K1', 'TGFB3', 'MT2A', 'AMPD3', 'UGP2', 'SULT2B1', 'COL5A1', 'TPST2', 'GAPDHS', 'GPC1', 'SIAH2', 'PKP1', 'PGM2', 'SERPINE1', 'IDS', 'PGM1', 'GBE1', 'ADORA2B', 'ATP7A', 'PGAM2', 'EFNA1', 'PRDX5', 'GPC4'}, 'HALLMARK_CHOLESTEROL_HOMEOSTASIS': {'ABCA2', 'FDFT1', 'LGMN', 'SREBF2', 'ATF3', 'FBXO6', 'ALCAM', 'ANXA13', 'NSDHL', 'SC5D', 'TRIB3', 'SEMA3B', 'IDI1', 'S100A11', 'FASN', 'LDLR', 'GSTM2', 'CXCL16', 'ALDOC', 'MVK', 'ECH1', 'LPL', nan, 'CHKA', 'PCYT2', 'ATF5', 'DHCR7', 'EBP', 'ANTXR2', 'SCD', 'ACTG1', 'FADS2', 'PNRC1', 'ADH4', 'LGALS3', 'HMGCS1', 'FDPS', 'PDK3', 'ETHE1', 'SQLE', 'GUSB', 'ATXN2', 'GLDC', ' ...

# %% [markdown]
# ### Reading in a gene set library that is saved as a gmt file
# A gmt file is a tab separated file where each line belongs to a gene set as:
#
# gene_set_name_1   description  gene_1  gene_2  ....    gene_n
#
# GMT files can be downloaded from https://www.gsea-msigdb.org/gsea/msigdb/.

# %%
with open("data/hallmark_library.gmt", "r") as gmt_file:
    # Skipping the description column
    gmt_grouping = {line.split("\t")[0] : line.strip("\n").split("\t")[2:] for line in gmt_file}

print(gmt_grouping)
# Out:
# {'HALLMARK_ADIPOGENESIS': ['ABCA1', 'ABCB8', 'ACAA2', 'ACADL', 'ACADM', 'ACADS', 'ACLY', 'ACO2', 'ACOX1', 'ADCY6', 'ADIG', 'ADIPOQ', 'ADIPOR2', 'AGPAT3', 'AIFM1', 'AK2', 'ALDH2', 'ALDOA', 'ANGPT1', 'ANGPTL4', 'APLP2', 'APOE', 'ARAF', 'ARL4A', 'ATL2', 'ATP1B3', 'ATP5PO', 'BAZ2A', 'BCKDHA', 'BCL2L13', 'BCL6', 'C3', 'CAT', 'CAVIN1', 'CAVIN2', 'CCNG2', 'CD151', 'CD302', 'CD36', 'CDKN2C', 'CHCHD10', 'CHUK', 'CIDEA', 'CMBL', 'CMPK1', 'COL15A1', 'COL4A1', 'COQ3', 'COQ5', 'COQ9', 'COX6A1', 'COX7B', 'COX8A', 'CPT2', 'CRAT', 'CS', 'CYC1', 'CYP4B1', 'DBT', 'DDT', 'DECR1', 'DGAT1', 'DHCR7', 'DHRS7', 'DHRS7B', 'DLAT', 'DLD', 'DNAJB9', 'DNAJC15', 'DRAM2', 'ECH1', 'ECHS1', 'ELMOD3', 'ELOVL6', 'ENPP2', 'EPHX2', 'ESRRA', 'ESYT1', 'ETFB', 'FABP4', 'FAH', 'FZD4', 'G3BP2', 'GADD45A', 'GBE1', 'GHITM', 'GPAM', 'GPAT4', 'GPD2', 'GPHN', 'GPX3', 'GPX4', 'GRPEL1', 'HADH', 'HIBCH', 'HSPB8', 'IDH1', 'IDH3A', 'IDH3G', 'IFNGR1', 'IMMT', 'ITGA7', 'ITIH5', 'ITSN1', 'JAGN1', 'LAMA4', 'LEP', 'LIFR', 'LIPE', 'LPCAT3', 'LPL', 'LTC4S', 'MAP4K3', 'MCCC1', 'MDH2', 'ME1', 'MGLL', 'MGST3', 'MIGA2', 'MRAP', 'MRPL15', 'MTARC2', 'MTCH2', 'MYLK', 'NABP1', 'NDUFA5', 'NDUFAB1', 'NDUFB7', 'NDUFS3', 'NKIRAS1', 'NMT1', 'OMD', 'ORM1', 'PDCD4', 'PEMT', 'PEX14', 'PFKFB3', 'PFKL', 'PGM1', 'PHLDB1', 'PHYH', 'PIM3', 'PLIN2', 'POR', 'PPARG', 'PPM1B', 'PPP1R15B', 'PRDX3', 'PREB', 'PTCD3', 'PTGER3', 'QDPR', 'RAB34', 'REEP5', 'REEP6', 'RETN', 'RETSAT', 'RIOK3', 'RMDN3', 'RNF11', 'RREB1', 'RTN3', 'SAMM50', 'SCARB1', 'SCP2', 'SDHB', 'SDHC', 'SLC19A1', 'SLC1A5', 'SLC25A1', 'SLC25A10', 'SLC27A1', 'SLC5A6', 'SLC66A3', 'SNCG', 'SOD1', 'SORBS1', 'SOWAHC', 'SPARCL1', 'SQOR', 'SSPN', 'STAT5A', 'STOM', 'SUCLG1', 'SULT1A1', 'TALDO1', 'TANK', 'TKT', 'TOB1', 'TST', 'UBC', 'UBQLN1', 'UCK1', 'UCP2', 'UQCR10', 'UQCR11', 'UQCRC1', 'UQCRQ', 'VEGFB', 'YWHAG'], 'HALLMARK_ALLOGRAFT_REJECTION': ['AARS1', 'ABCE1', 'ABI1', 'ACHE', 'ACVR2A', 'AKT1', 'APBB1', 'B2M', 'BCAT1', 'BCL10', 'BCL3', 'BRCA1', 'C2', 'CAPG', 'CARTPT', 'CCL11', 'CCL13', 'CCL19', 'CCL2', 'CCL22', 'CCL4', 'CCL5', 'CCL7', 'CCND2', 'CCND3', 'CCR1', 'CCR2', 'CCR5', 'CD1D', 'CD2', 'CD247', 'CD28', 'CD3D', 'CD3E', 'CD3G', 'CD4', 'CD40', 'CD40LG', 'CD47', 'CD7', 'CD74', 'CD79A', 'CD80', 'CD86', 'CD8A', 'CD8B', 'CD96', 'CDKN2A', 'CFP', 'CRTAM', 'CSF1', 'CSK', 'CTSS', 'CXCL13', 'CXCL9', 'CXCR3', 'DARS1', 'DEGS1', 'DYRK3', 'EGFR', 'EIF3A', 'EIF3D', 'EIF3J', 'EIF4G3', 'EIF5A', 'ELANE', 'ELF4', 'EREG', 'ETS1', 'F2', 'F2R', 'FAS', 'FASLG', 'FCGR2B', 'FGR', 'FLNA', 'FYB1', 'GALNT1', 'GBP2', 'GCNT1', 'GLMN', 'GPR65', 'GZMA', 'GZMB', 'HCLS1', 'HDAC9', 'HIF1A', 'HLA-A', 'HLA-DMA', 'HLA-DMB', 'HLA-DOA', 'HLA-DOB', 'HLA-DQA1', 'HLA-DRA', 'HLA-E', 'HLA-G', 'ICAM1', 'ICOSLG', 'IFNAR2', 'IFNG', 'IFNGR1', 'IFNGR2', 'IGSF6', 'IKBKB', 'IL10', 'IL11', 'IL12A', 'IL12B', 'IL12RB1', 'IL13', 'IL15', 'IL16', 'IL18', 'IL18RAP', 'IL1B', 'IL2', 'IL27RA', 'IL2RA', 'IL2RB', 'IL2RG', 'IL4', 'IL4R', 'IL6', 'IL7', 'IL9', 'INHBA', 'INHBB', 'IRF4', 'IRF7', 'IRF8', 'ITGAL', 'ITGB2', 'ITK', 'JAK2', 'KLRD1', 'KRT1', 'LCK', 'LCP2', 'LIF', 'LTB', 'LY75', 'LY86', 'LYN', 'MAP3K7', 'MAP4K1', 'MBL2', 'MMP9', 'MRPL3', 'MTIF2', 'NCF4', 'NCK1', 'NCR1', 'NLRP3', 'NME1', 'NOS2', 'NPM1', 'PF4', 'PRF1', 'PRKCB', 'PRKCG', 'PSMB10', 'PTPN6', 'PTPRC', 'RARS1', 'RIPK2', 'RPL39', 'RPL3L', 'RPL9', 'RPS19', 'RPS3A', 'RPS9', 'SIT1', 'SOCS1', 'SOCS5', 'SPI1', 'SRGN', 'ST8SIA4', 'STAB1', 'STAT1', 'STAT4', 'TAP1', 'TAP2', 'TAPBP', 'TGFB1', 'TGFB2', 'THY1', 'TIMP1', 'TLR1', 'TLR2', 'TLR3', 'TLR6', 'TNF', 'TPD52', 'TRAF2', 'TRAT1', 'UBE2D1', 'UBE2N', 'WARS1', 'WAS', 'ZAP70'], 'HALLMARK_ANDROGEN_RESPONSE': ['ABCC4', 'ABHD2', 'ACSL3', 'ACTN1', 'ADAMTS1', 'ADRM1', 'AKAP12', 'AKT1', 'ALDH1A3', 'ANKH', 'APPBP2', 'ARID5B', 'AZGP1', 'B2M', 'B4GALT1', 'BMPR1B', 'CAMKK2', 'CCND1', 'CCND3', 'CDC14B', 'CDK6', 'CENPN', 'DBI', 'DHCR24', 'DNAJB9', 'ELK4', 'ELL2', 'ELOVL5', 'FADS1', 'FKBP5', 'GNAI3', 'GPD1L', 'GSR', 'GUCY1A1', 'H1-0', 'HERC3', 'HMGCR', 'HMGCS1', 'HOMER2', 'HPGD', 'HSD17B14', 'IDI1', 'INPP4B', 'INSIG1', 'IQG ...

# %% [markdown]
# ### Using GSEApy to download one of their many gene sets across several organisms
# GSEApy includes gene set libraries for 'Human', 'Mouse', 'Yeast', 'Worm', 'Fly', and 'Fish'

# %%
# Showing the number of gene set libraries for each organsim
for organism in ['Human', 'Mouse', 'Yeast', 'Worm', 'Fly', 'Fish']:
    print(f'There are {len(gseapy.get_library_name(organism = organism))} gene set libraries for {organism}')

# After choosing one of the library names from gseapy.get_library_name() for your organism, we can pull the library
# Here we will pull the MSigDB_Hallmark_2020 library for Human
gseapy_grouping = gseapy.get_library(name = 'MSigDB_Hallmark_2020', organism = 'Human')
print(gseapy_grouping)
# Out:
# There are 227 gene set libraries for Human
# There are 227 gene set libraries for Mouse
# There are 21 gene set libraries for Yeast
# There are 37 gene set libraries for Worm
# There are 38 gene set libraries for Fly
# There are 30 gene set libraries for Fish
# {'TNF-alpha Signaling via NF-kB': ['MARCKS', 'IL23A', 'NINJ1', 'TNFSF9', 'SIK1', 'ATF3', 'SERPINE1', 'MYC', 'HES1', 'CCN1', 'CCNL1', 'EGR1', 'EGR2', 'EGR3', 'JAG1', 'ABCA1', 'GADD45B', 'GADD45A', 'KLF10', 'PLK2', 'EIF1', 'EHD1', 'FOSL2', 'FOSL1', 'GPR183', 'PLPP3', 'IFIT2', 'ICAM1', 'ZC3H12A', 'IER2', 'IL12B', 'IER5', 'JUNB', 'IER3', 'STAT5A', 'DUSP5', 'EDN1', 'DUSP4', 'JUN', 'DUSP1', 'DUSP2', 'TSC22D1', 'CCL20', 'SPHK1', 'LIF', 'IL18', 'TUBB2A', 'RHOB', 'VEGFA', 'IL1A', 'PTPRE', 'TLR2', 'IL1B', 'BHLHE40', 'CLCF1', 'ID2', 'REL', 'FJX1', 'SGK1', 'BTG3', 'BTG2', 'BTG1', 'SDC4', 'LITAF', 'AREG', 'SOCS3', 'PANX1', 'RIPK2', 'NFIL3', 'SERPINB2', 'GCH1', 'IFNGR2', 'G0S2', 'FOS', 'F3', 'SERPINB8', 'SPSB1', 'FOSB', 'PER1', 'F2RL1', 'HBEGF', 'CD44', 'TRIP10', 'CDKN1A', 'PTGER4', 'PTGS2', 'IFIH1', 'NAMPT', 'OLR1', 'ICOSLG', 'PHLDA1', 'ZBTB10', 'TAP1', 'PNRC1', 'CXCL10', 'CXCL11', 'IL6ST', 'CD69', 'SQSTM1', 'RELA', 'CD83', 'CSF2', 'CSF1', 'CD80', 'PPP1R15A', 'TNC', 'TNF', 'RELB', 'TANK', 'ZFP36', 'CCND1', 'RNF19B', 'CCRL2', 'DENND5A', 'MAP3K8', 'PHLDA2', 'LDLR', 'SLC16A6', 'SMAD3', 'TGIF1', 'MAP2K3', 'DDX58', 'INHBA', 'TRAF1', 'NFKB1', 'NFKB2', 'GEM', 'MAFF', 'NR4A3', 'RCAN1', 'EFNA1', 'NR4A2', 'MXD1', 'BIRC2', 'BIRC3', 'YRDC', 'IL7R', 'PFKFB3', 'IRS2', 'SLC2A3', 'PLAU', 'SAT1', 'SLC2A6', 'ETS2', 'NR4A1', 'SNN', 'PMEPA1', 'TNFRSF9', 'MSC', 'TIPARP', 'LAMB3', 'GFPT2', 'CFLAR', 'TNIP1', 'IRF1', 'NFKBIA', 'BMP2', 'IL6', 'TNIP2', 'BCL6', 'BCL3', 'NFKBIE', 'NFE2L2', 'B4GALT1', 'NFAT5', 'BCL2A1', 'TNFAIP8', 'TNFAIP6', 'TNFAIP3', 'CXCL2', 'CXCL1', 'TNFAIP2', 'CXCL3', 'CXCL6', 'FUT4', 'DRAM1', 'DNAJB4', 'PDE4B', 'PDLIM5', 'MCL1', 'KDM6B', 'IL15RA', 'PLAUR', 'ATP2B1', 'KLF4', 'KLF2', 'SOD2', 'KLF9', 'KLF6', 'ACKR3', 'PTX3', 'B4GALT5', 'TRIB1', 'CEBPB', 'CEBPD', 'PLEK', 'CCL5', 'KYNU', 'CCL4', 'CCL2'], 'Hypoxia': ['WSB1', 'JMJD6', 'XPNPEP1', 'RRAGD', 'PPP1R3C', 'MT1E', 'TES', 'ATF3', 'SERPINE1', 'GLRX', 'UGP2', 'NOCT', 'MXI1', 'DPYSL4', 'CCN5', 'CCN2', 'PPARGC1A', 'CCN1', 'DTNA', 'SIAH2', 'MIF', 'PRKCA', 'EXT1', 'FOSL2', 'SLC6A6', 'SULT2B1', 'BCAN', 'LALBA', 'CHST2', 'SDC2', 'HOXB9', 'CHST3', 'LXN', 'NEDD4L', 'PDGFB', 'ENO1', 'ENO2', 'ENO3', 'RBPJ', 'MT2A', 'PLAC8', 'PRDX5', 'HMOX1', 'PDK1', 'IER3', 'PDK3', 'EDN2', 'ANXA2', 'JUN', 'DUSP1', 'TPI1', 'AMPD3', 'CP', 'VEGFA', 'P4HA1', 'P4HA2', 'BHLHE40', 'CCNG2', 'PAM', 'ALDOC', 'ALDOB', 'ALDOA', 'GPI', 'BTG1', 'CITED2', 'SDC3', 'SDC4', 'STC1', 'ADM', 'STC2', 'VLDLR', 'BRS3', 'LDHC', 'LDHA', 'CSRP2', 'IDS', 'NFIL3', 'PCK1', 'TPD52', 'PKLR', 'PGAM2', 'GAA', 'FOS', 'BGN', 'F3', 'TPST2', 'ANGPTL4', 'PLIN2', 'INHA', 'ERRFI1', 'SRPX', 'CDKN1B', 'CDKN1C', 'ERO1A', 'HEXA', 'CDKN1A', 'NCAN', 'GBE1', 'GCNT2', 'PYGM', 'GYS1', 'NDST2', 'NDST1', 'AKAP12', 'STBD1', 'CXCR4', 'CA12', 'HS3ST1', 'MAP3K1', 'TGFB3', 'CAVIN1', 'CAVIN3', 'KLHL24', 'PNRC1', 'SAP30', 'GCK', 'ILVBL', 'COL5A1', 'TGFBI', 'GAPDHS', 'S100A4', 'PKP1', 'PPP1R15A', 'HDLBP', 'EGFR', 'FOXO3', 'NDRG1', 'KIF5A', 'ZFP36', 'GPC1', 'HAS1', 'GPC4', 'GPC3', 'PPFIA4', 'IGFBP1', 'BNIP3L', 'IGFBP3', 'B3GALT6', 'PGF', 'MAFF', 'EFNA1', 'ISG20', 'EFNA3', 'LOX', 'PFKFB3', 'IRS2', 'SLC2A1', 'AK4', 'SLC2A3', 'SLC2A5', 'ETS1', 'RORA', 'TGM2', 'FAM162A', 'PIM1', 'ANKZF1', 'TIPARP', 'HSPA5', 'CAV1', 'GALK1', 'GRHPR', 'IL6', 'ADORA2B', 'MYH9', 'BCL2', 'FBP1', 'TMEM45A', 'SLC25A1', 'TNFAIP3', 'HK1', 'HK2', 'CASP6', 'PGK1', 'B4GALNT2', 'SLC37A4', 'TKTL1', 'TPBG', 'PLAUR', 'DCN', 'SELENBP1', 'KLF7', 'NAGK', 'KLF6', 'PFKL', 'DDIT4', 'DDIT3', 'ACKR3', 'KDELR3', 'GAPDH', 'PFKP', 'KDM3A', 'ZNF292', 'NR3C1', 'PHKG1', 'VHL', 'ATP7A', 'PGM2', 'SCARB1', 'LARGE1', 'PGM1'], 'Cholesterol Homeostasis': ['STARD4', 'GSTM2', 'CHKA', 'HMGCS1', 'TNFRSF12A', 'ANXA5', 'ECH1', 'GPX8', 'PNRC1', 'CPEB2', 'SCD', 'CD9', 'ETHE1', 'ALDOC', 'DHCR7', 'IDI1', 'ATF3', 'CLU', 'HSD17B7', 'ANTXR2', 'CXCL16', 'ACAT2', 'ATXN2', 'PMVK', 'SC5D', 'MAL2', 'STX5', 'NFIL3', 'ACSS2', 'FDFT1', 'LDLR', 'S100A11', 'ABCA2', 'FDPS', 'NIBAN1', 'SREBF2', 'JAG1', 'CYP51A1', 'PCYT2', 'ANXA13', 'TP53INP1', 'AVPR1A', 'LSS', 'P ...

# %% [markdown]
# ### Saving a Library for scMKL Grouping
# If you plan doing multiple train/test splits or running with different sparsities (alpha), it is recommened that the grouping dictionaries are saved as a pickle.
# As pickle files are byte-streams, they are very fast to read-in.

# %%
# Saving a dictionary as a pickle file

# with open('your_filename.pkl', 'wb') as output:
#     pickle.dump(group_dict, output)
